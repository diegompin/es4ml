# %%
import numpy as np
from network_statistical_analysis import NetworkStatisticalAnalysis

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
random_values = np.array([12, 14, 23, 13, 29])
statistical_analysis = NetworkStatisticalAnalysis(random_values, 43)
statistical_analysis.plot_confidence_interval(1)
